# %% [markdown]
# # Rating examples (raw labels)

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from aitraf.data_ops.schema import LabelsSchema

PROJECT_ROOT = Path("..").resolve()
DATA_DIR = PROJECT_ROOT / "data"
LABELS_PATH = DATA_DIR / "labels.jsonl"

pd.set_option("display.max_colwidth", None)

SAMPLES_PER_RATING = 2
RNG_SEED = 1
rng = np.random.default_rng(RNG_SEED)

# %%
labels_df = pd.read_json(LABELS_PATH, lines=True, dtype=LabelsSchema.types)
ratings = sorted(labels_df["execution_score"].dropna().unique())

rows = []
for rating in ratings:
    rating_rows = labels_df[labels_df["execution_score"] == rating]
    if len(rating_rows) < SAMPLES_PER_RATING:
        raise RuntimeError(f"Not enough rows for rating {rating}.")
    sample_idx = rng.choice(len(rating_rows), size=SAMPLES_PER_RATING, replace=False)
    samples = rating_rows.iloc[sample_idx]
    for _, sample in samples.iterrows():
        rows.append(
            {
                "rating": sample["execution_score"],
                "trick": sample["trick"],
            }
        )

pd.DataFrame(rows)
# Out:
#    rating  \
# 0       1
# 1       1
# 2       2
# 3       2
# 4       3
# 5       3
# 6       4
# 7       4
#
#                                                                                                   description  \
# 0                                                     Short and i just don't like that landing. Looks awkward
# 1                                                                         Very sketchy landing + slow overall
# 2                                                                                      way too slow and short
# 3                body position is off. Great speed though. Clear loss of balance in the end, forced landing.
# 4  Pose should be lower, balance looks ok. I just don't like the landing, it looks awkward. can't explain it.
# 5                                                Confident form, landing a bit unclean, not complete obstacle
# 6      The balance itself - not perfect. But everything else around it, the landing, just looks so in control
# 7                                                    Body position not low enough, but otherwise looks great.
#
#         trick
# 0        soul
# 1  fs-savanah
# 2     ao-soul
# 3    top-soul
# 4   bs-royale
# 5     ao-soul
# 6       mizou
# 7   bs-royale
