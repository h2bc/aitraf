# %% [markdown]
# # Testing pose estimation

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    os.chdir(project_root)

# %%
import torch
print(torch.__version__, torch.version.cuda, torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 2.9.0+cu128 12.8 True
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import cv2
import matplotlib.pyplot as plt
from paths import DATA_DIR, MODELS_DIR
from ultralytics import YOLO

# %% [markdown]
# #### Load video

# %%
# Load Video from Data Folder
video_path = DATA_DIR / "vileika_example_1.MOV"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise IOError(f"Cannot open video file: {video_path}")
else:
    print(f"Video loaded: {video_path}")
# Out:
# Video loaded: /home/tufman/src/uni/aitraf/data/vileika_example_1.MOV

# %% [markdown]
# #### Extract a frame

# %%
# Extract Middle Frame from Video
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
frame_idx = 20
cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
ret, frame = cap.read()

if not ret:
    raise ValueError(f"Could not read frame at index {frame_idx}")
else:
    print(f"Extracted frame {frame_idx} of {frame_count}")
# Out:
# Extracted frame 20 of 350

# %%
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(frame_rgb)
plt.title(f"Frame: {frame_idx}")
plt.axis('off')
plt.show()

# %% [markdown]
# #### Test on a frame

# %%
model = YOLO(MODELS_DIR / "yolo11n-pose.pt")
frame_pose = model.predict(source=frame, device=0, imgsz=640, conf=0.25, verbose=False)

# visualize
vis = frame_pose[0].plot()
plt.imshow(cv2.cvtColor(vis, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# #### Test on full video

# %%
results = model.predict(
    source=DATA_DIR / "vileika_example_1.MOV",
    device=0,       # GPU
    imgsz=640,
    conf=0.25,
    save=True,
    verbose=False
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# Results saved to /home/tufman/src/uni/aitraf/runs/pose/predict3
